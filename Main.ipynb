# %% [markdown]
# # Setup

# %% [markdown]
# ## Test Kernel is working

# %%
print ("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# ## Import relevant libraries

# %%
import os
import requests
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Attempt import of data and display top 5 rows

# %% [markdown]
# ## Attempt to call url to download data

# %%
url= "https://www.metoffice.gov.uk/pub/data/weather/uk/climate/datasets/Sunshine/date/East_Anglia.txt"
response = requests.get(url)
print (response.text)
# Out:
# Areal values from HadUK-Grid 1km gridded climate data from land surface network
# Source: Met Office National Climate Information Centre
# Monthly, seasonal and annual total duration of bright sunshine for East Anglia
# Areal series, starting in 1910
# Last updated 01-Nov-2025 10:38
# year    jan    feb    mar    apr    may    jun    jul    aug    sep    oct    nov    dec     win     spr     sum     aut     ann
# 1910   71.2   75.2  155.6  133.5  211.0  192.9  118.5  167.0  124.1   72.9   80.8   30.7     ---   500.1   478.4   277.8  1433.4
# 1911   60.8   68.9   89.6  161.2  224.4  218.4  312.8  238.4  212.8   98.6   58.6   43.1   160.4   475.3   769.6   370.0  1787.6
# 1912   35.0   53.4   94.2  241.7  174.5  192.9  163.0  107.8  112.2  128.6   36.0   25.8   131.5   510.4   463.6   276.7  1365.0
# 1913   45.9   67.7  104.6  130.9  201.3  201.7  101.3  165.4  136.9  108.3   83.9   40.7   139.3   436.7   468.5   329.1  1388.5
# 1914   38.6   92.4   99.3  230.8  204.3  242.3  173.4  191.0  194.6   76.3   67.2   39.5   171.8   534.5   606.7   338.1  1649.8
# 1915   34.1   73.0   98.9  173.2  221.0  231.3  181.5  168.8  172.2   77.4   71.5   37.4   146.6   493.1   581.6   321.0  1540.2
# 1916   53.5   71.5   58.9  190.5  182.9  130.7  145.8  165.9  107.9   87.8   69.2   24.2   162.4   432.2   442.4   264.9  1288.8
# 1917   23.0   42.7   79.4  131.9  242.5  224.5  227.3  159.5  165.9  150.3   58.0   60.0    89.9   453.8   611.2   374.2  1564.9
# 1918   61.3   78.2  135.5  103.0  226.8  229.9  201.5  185.9  152.0   70.3   69.2   33.4   199.5   465.4   617.3   291.5  1547.1
# 1919   36.1   50.2   89.8  116.1  267.8  225.1  115.7  216.2  164.4  132.4   51.8   31.0   119.7   473.6   557.1   348.6  1496.7
# 1920   53.1   89.0  141.6   92.4  234.3  229.0  159.9  146.3  107.3  165.9   82.6   30.3   173.1   468.3   535.1   355.8  1531.5
# 1921   46.6   78.1  138.4  206.7  245.5  210.7  262.5  177.8  172.0  148.2   70.3   42.1   155.0   590.6   650.9   390.5  1798.9
# 1922   36.2  102.2  102.9  167.0  276.6  227.5  149.0  147.8  128.6  134.7   56.0   47.4   180.5   546.5   524.3   319.4  1575.9
# 1923   61.7   57.4  100.5  146.3  152.7  130.5  225.4  245.1  183.8   92.6   93.0   37.5   166.5   399.5   601.0   369.4  1526.5
# 1924   59.4   45.9  168.2  148.1  183.5  197.6  236.0  163.1  120.4   94.4   44.8   47.9   142.9   499.8   596.8   259.7  1509.5
# 1925   53.5   68.7   90.4  136.9  220.9  250.3  192.4  147.3  118.6  102.6   83.1   59.9   170.1   448.2   590.0   304.3  1524.5
# 1926   48.3   45.7  121.3  111.4  179.1  182.3  184.9  204.9  142.4  113.8   45.5   56.6   153.8   411.8   572.1   301.7  1436.2
# 2010   51.7   54.0  115.7  215.5  213.0  229.8  191.3  145.3  129.1  105.6   54.8   41.5   170.7   544.3   566.4   289.5  1547.4
# 2011   40.6   39.3  113.5  215.8  233.0  208.9  165.0  152.6  174.7  152.1   64.2   66.7   121.4   562.3   526.4   390.9  1626.3
# 2012   72.1   83.6  155.6  136.8  170.1  146.4  171.9  188.9  179.0   92.0   74.5   51.3   222.3   462.4   507.2   345.5  1522.1
# 2013   51.0   59.5   66.8  193.5  193.4  169.4  263.3  217.1  144.2   93.1   76.4   62.4   161.8   453.6   649.8   313.6  1590.0
# 2014   64.5  102.2  157.7  155.7  185.3  211.1  229.0  200.1  132.4  113.3   52.2   79.6   229.1   498.7   640.2   297.9  1683.1
# 2015   71.6   88.3  144.6  215.8  193.4  227.5  202.9  163.5  170.7   97.9   41.7   44.2   239.5   553.8   593.9   310.3  1662.1
# 2016   54.2   93.5  129.0  175.7  203.8  132.0  226.5  240.5  140.9  105.3   86.5   53.5   191.9   508.4   599.0   332.8  1641.3
# 2017   67.3   56.3  127.9  182.8  183.4  210.2  188.5  191.5  124.1   89.3   86.6   60.6   177.0   494.1   590.2   300.0  1568.4
# 2018   62.3   99.1   75.6  125.0  256.6  241.1  282.5  200.8  176.8  158.4   85.0   52.5   222.0   457.3   724.3   420.2  1815.8
# 2019   60.1  137.2  133.3  192.1  209.2  177.0  205.1  241.7  178.1   82.5   54.9   66.4   249.8   534.6   623.8   315.6  1737.6
# 2020   59.7   90.4  166.4  249.0  309.3  216.1  179.6  182.2  176.9   62.9   72.5   46.1   216.5   724.7   577.8   312.3  1811.0
# 2021   43.7   75.9  110.6  217.5  171.3  205.9  182.6  127.3  155.0   99.6   85.2   27.3   165.7   499.4   515.8   339.7  1501.8
# 2022   96.0   96.3  182.1  206.7  188.1  248.3  235.0  256.8  138.4  150.6   58.8   64.7   219.7   576.9   740.2   347.8  1922.0
# 2023   79.6  104.6   78.6  184.5  211.7  260.5  171.3  201.4  175.3  107.9   89.2   30.6   248.8   474.9   633.2   372.4  1695.2
# 2024   80.1   59.5   98.2  142.4  195.4  234.5  200.4  222.8  142.3  104.6   58.7   29.8   170.2   436.0   657.7   305.6  1568.7
# 2025   73.5   69.5  222.0  269.2  252.8  276.8  212.1  211.0  183.1   76.9                 172.8   744.1   699.9

# %% [markdown]
# ## Check file exists

# %%
# First, let's import os to check if file exists
import os

raw_file_path = '/home/lnx_workspaces/bpp_projects/bpp_module1_project/data/weather/sunshine/east_anglia_sun.txt'
print(f"File exists: {os.path.exists(raw_file_path)}")

# If file exists, let's try to read first few lines directly
if os.path.exists(raw_file_path):
    with open(raw_file_path, 'r') as file:
        print("\nFirst few lines of the file:")
        for i, line in enumerate(file):
            if i < 3:  # Print first 3 lines
                print(line.strip())
# Out:
# File exists: True
#
# First few lines of the file:
# Areal values from HadUK-Grid 1km gridded climate data from land surface network
# Source: Met Office National Climate Information Centre
# Monthly, seasonal and annual total duration of bright sunshine for East Anglia

# %% [markdown]
# ## Present first five rows of file to assess for processing

# %%
# Read the raw text file
with open(raw_file_path, 'r') as file:
    print("First 5 lines of raw file:")
    for i, line in enumerate(file):
        if i < 5:
            print(f"Line {i+1}: {repr(line)}")  # repr() shows whitespace characters
# Out:
# First 5 lines of raw file:
# Line 1: 'Areal values from HadUK-Grid 1km gridded climate data from land surface network\n'
# Line 2: 'Source: Met Office National Climate Information Centre\n'
# Line 3: 'Monthly, seasonal and annual total duration of bright sunshine for East Anglia\n'
# Line 4: 'Areal series, starting in 1910\n'
# Line 5: 'Last updated 01-Nov-2025 10:38\n'

# %% [markdown]
# This indicates the first five rows of data are only **Contextual information** and not part of the dataset proper. This is not needed and will need to be removed for the purposes of data analysis.

# %%
# Explore more rows to identify where the data starts
with open(raw_file_path, 'r') as file:
    print("First 5 lines of raw file:")
    for i, line in enumerate(file):
        if i < 10:
            print(f"Line {i+1}: {repr(line)}")  # repr() shows whitespace characters
# Out:
# First 5 lines of raw file:
# Line 1: 'Areal values from HadUK-Grid 1km gridded climate data from land surface network\n'
# Line 2: 'Source: Met Office National Climate Information Centre\n'
# Line 3: 'Monthly, seasonal and annual total duration of bright sunshine for East Anglia\n'
# Line 4: 'Areal series, starting in 1910\n'
# Line 5: 'Last updated 01-Nov-2025 10:38\n'
# Line 6: 'year    jan    feb    mar    apr    may    jun    jul    aug    sep    oct    nov    dec     win     spr     sum     aut     ann\n'
# Line 7: '1910   71.2   75.2  155.6  133.5  211.0  192.9  118.5  167.0  124.1   72.9   80.8   30.7     ---   500.1   478.4   277.8  1433.4\n'
# Line 8: '1911   60.8   68.9   89.6  161.2  224.4  218.4  312.8  238.4  212.8   98.6   58.6   43.1   160.4   475.3   769.6   370.0  1787.6\n'
# Line 9: '1912   35.0   53.4   94.2  241.7  174.5  192.9  163.0  107.8  112.2  128.6   36.0   25.8   131.5   510.4   463.6   276.7  1365.0\n'
# Line 10: '1913   45.9   67.7  104.6  130.9  201.3  201.7  101.3  165.4  136.9  108.3   83.9   40.7   139.3   436.7   468.5   329.1  1388.5\n'

# %% [markdown]
# The first row of data starts at Line 7, with the headers of columns on Line 6.

# %% [markdown]
# ## First five lines of actual data

# %% [markdown]
# ### Headers

# %%
# Read the raw text file
with open(raw_file_path, 'r') as file:
    print("Headers of columns:")
    for i, line in enumerate(file):
        if i == 5:
            print(f"Line {i+1}: {repr(line)}")  # repr() shows whitespace characters
# Out:
# Headers of columns:
# Line 6: 'year    jan    feb    mar    apr    may    jun    jul    aug    sep    oct    nov    dec     win     spr     sum     aut     ann\n'

# %% [markdown]
# ### First five lines of actual data

# %%
# Read the raw text file
with open(raw_file_path, 'r') as file:
    print("First 5 lines of raw file:")
    for i, line in enumerate(file):
        if i > 5 and i < 10:
            print(f"Line {i+1}: {repr(line)}")  # repr() shows whitespace characters
# Out:
# First 5 lines of raw file:
# Line 7: '1910   71.2   75.2  155.6  133.5  211.0  192.9  118.5  167.0  124.1   72.9   80.8   30.7     ---   500.1   478.4   277.8  1433.4\n'
# Line 8: '1911   60.8   68.9   89.6  161.2  224.4  218.4  312.8  238.4  212.8   98.6   58.6   43.1   160.4   475.3   769.6   370.0  1787.6\n'
# Line 9: '1912   35.0   53.4   94.2  241.7  174.5  192.9  163.0  107.8  112.2  128.6   36.0   25.8   131.5   510.4   463.6   276.7  1365.0\n'
# Line 10: '1913   45.9   67.7  104.6  130.9  201.3  201.7  101.3  165.4  136.9  108.3   83.9   40.7   139.3   436.7   468.5   329.1  1388.5\n'

# %% [markdown]
# ## Try reading in

# %% [markdown]
# ### Direct reading of file as csv with pandas

# %%
# Try reading with explicit encoding and error handling
try:
    df = pd.read_csv(raw_file_path, encoding='utf-8')
    print("\nDataframe info:")
    print(df.info())
    print("\nFirst 5 rows:")
    print(df.head())
except Exception as e:
    print(f"Error: {str(e)}")
# Out:
# Error: Error tokenizing data. C error: Expected 1 fields in line 3, saw 2

# %% [markdown]
# This shows that the data cannot be read in. Suggesting that pandas is unable to determine the correct delimiter in the CSV file. This is down to the file actually being a .txt file, and being delimited by both tabs and spaces.

# %% [markdown]
# ### Attempt to handle variable spacing and whitespace

# %%
try:
    # Read with flexible whitespace handling
    df = pd.read_csv(raw_file_path, 
                     delim_whitespace=True,  # Handle variable spacing
                     skipinitialspace=True,   # Skip leading spaces
                     skip_blank_lines=True)   # Skip empty lines
    
    print("\nDataframe info:")
    print(df.info())
    print("\nFirst 5 rows:")
    print(df.head())
except Exception as e:
    print(f"Error: {str(e)}")
# Out:
# Error: Error tokenizing data. C error: Expected 12 fields in line 6, saw 18
# /tmp/ipykernel_1493999/1667402197.py:3: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(raw_file_path,

# %% [markdown]
# This appears to fail as it is expecting fewer columns than are presented in the data table propoer. This is likely due to the contextual inforamtion presented at the start of the file.

# %% [markdown]
# ## Try with text file where contextual data has been stripped out

# %% [markdown]
# ### Check file exists

# %%
# First, let's import os to check if file exists
import os

stripped_file_path = '/home/lnx_workspaces/bpp_projects/bpp_module1_project/data/weather/sunshine/east_anglia_sun_stripped.txt'
print(f"File exists: {os.path.exists(stripped_file_path)}")

# If file exists, let's try to read first few lines directly
if os.path.exists(stripped_file_path):
    with open(stripped_file_path, 'r') as file:
        print("\nFirst few lines of the file:")
        for i, line in enumerate(file):
            if i < 3:  # Print first 3 lines
                print(line.strip())
# Out:
# File exists: True
#
# First few lines of the file:
# year    jan    feb    mar    apr    may    jun    jul    aug    sep    oct    nov    dec     win     spr     sum     aut     ann
# 1910   71.2   75.2  155.6  133.5  211.0  192.9  118.5  167.0  124.1   72.9   80.8   30.7     ---   500.1   478.4   277.8  1433.4
# 1911   60.8   68.9   89.6  161.2  224.4  218.4  312.8  238.4  212.8   98.6   58.6   43.1   160.4   475.3   769.6   370.0  1787.6

# %% [markdown]
# This shows the first three line of the file. The first being the column headers, and then two rows of data.

# %% [markdown]
# ## Try just reading straight into pandas

# %%
# Try reading with explicit encoding and error handling
try:
    df = pd.read_csv(stripped_file_path, encoding='utf-8')
    print("\nDataframe info:")
    print(df.info())
    print("\nFirst 5 rows:")
    print(df.head())
except Exception as e:
    print(f"Error: {str(e)}")
# Out:
# Dataframe info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116 entries, 0 to 115
# Data columns (total 1 columns):
#  #   Column                                                                                                                            Non-Null Count  Dtype
# ---  ------                                                                                                                            --------------  -----
#  0   year    jan    feb    mar    apr    may    jun    jul    aug    sep    oct    nov    dec     win     spr     sum     aut     ann  116 non-null    object
# dtypes: object(1)
# memory usage: 1.0+ KB
# None
#
# First 5 rows:
#   year    jan    feb    mar    apr    may    jun    jul    aug    sep    oct    nov    dec     win     spr     sum     aut     ann
# 0  1910   71.2   75.2  155.6  133.5  211.0  192.9...
# 1  1911   60.8   68.9   89.6  161.2  224.4  218.4...
# 2  1912   35.0   53.4   94.2  241.7  174.5  192.9...
# 3  1913   45.9   67.7  104.6  130.9  201.3  201.7...
# 4  1914   38.6   92.4   99.3  230.8  204.3  242.3...

# %% [markdown]
# ## See how this is handled with the additional parameters stripping out the whitespace

# %%
try:
    # Read with flexible whitespace handling
    df = pd.read_csv(stripped_file_path, 
                     delim_whitespace=True,  # Handle variable spacing
                     skipinitialspace=True,   # Skip leading spaces
                     skip_blank_lines=True)   # Skip empty lines
    
    print("\nDataframe info:")
    print(df.info())
    print("\nFirst 5 rows:")
    print(df.head())
except Exception as e:
    print(f"Error: {str(e)}")
# Out:
# Dataframe info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116 entries, 0 to 115
# Data columns (total 18 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    116 non-null    int64
#  1   jan     116 non-null    float64
#  2   feb     116 non-null    float64
#  3   mar     116 non-null    float64
#  4   apr     116 non-null    float64
#  5   may     116 non-null    float64
#  6   jun     116 non-null    float64
#  7   jul     116 non-null    float64
#  8   aug     116 non-null    float64
#  9   sep     116 non-null    float64
#  10  oct     116 non-null    float64
#  11  nov     116 non-null    float64
#  12  dec     116 non-null    float64
#  13  win     116 non-null    object
#  14  spr     115 non-null    float64
#  15  sum     115 non-null    float64
#  16  aut     115 non-null    float64
#  17  ann     115 non-null    float64
# dtypes: float64(16), int64(1), object(1)
# memory usage: 16.4+ KB
# None
#
# First 5 rows:
#    year   jan   feb    mar    apr    may    jun    jul    aug    sep    oct  \
# 0  1910  71.2  75.2  155.6  133.5  211.0  192.9  118.5  167.0  124.1   72.9
# 1  1911  60.8  68.9   89.6  161.2  224.4  218.4  312.8  238.4  212.8   98.6
# 2  1912  35.0  53.4   94.2  241.7  174.5  192.9  163.0  107.8  112.2  128.6
# 3  1913  45.9  67.7  104.6  130.9  201.3  201.7  101.3  165.4  136.9  108.3
# 4  1914  38.6  92.4   99.3  230.8  204.3  242.3  173.4  191.0  194.6   76.3
#
#     nov   dec    win    spr    sum    aut     ann
# 0  80.8  30.7    ---  500.1  478.4  277.8  1433.4
# 1  58.6  43.1  160.4  475.3  769.6  370.0  1787.6
# 2  36.0  25.8  131.5  510.4  463.6  276.7  1365.0
# 3  83.9  40.7  139.3  436.7  468.5  329.1  1388.5
# 4  67.2  39.5  171.8  534.5  606.7  338.1  1649.8
# /tmp/ipykernel_1493999/1490551202.py:3: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(stripped_file_path,

# %% [markdown]
# # Process whole file

# %% [markdown]
# ## Read raw file into a pandas dataframe

# %%
# Path to data: /home/lnx_workspaces/bpp_projects/bpp_module1_project/data/weather/sunshine/east_anglia_sun.csv
df = pd.read_csv(raw_file_path, sep="\s+", skiprows=5, header=0)
df.head(5)
# Out:
#    year   jan   feb    mar    apr    may    jun    jul    aug    sep    oct  \
# 0  1910  71.2  75.2  155.6  133.5  211.0  192.9  118.5  167.0  124.1   72.9
# 1  1911  60.8  68.9   89.6  161.2  224.4  218.4  312.8  238.4  212.8   98.6
# 2  1912  35.0  53.4   94.2  241.7  174.5  192.9  163.0  107.8  112.2  128.6
# 3  1913  45.9  67.7  104.6  130.9  201.3  201.7  101.3  165.4  136.9  108.3
# 4  1914  38.6  92.4   99.3  230.8  204.3  242.3  173.4  191.0  194.6   76.3
#
#     nov   dec    win    spr    sum    aut     ann
# 0  80.8  30.7    ---  500.1  478.4  277.8  1433.4
# 1  58.6  43.1  160.4  475.3  769.6  370.0  1787.6
# 2  36.0  25.8  131.5  510.4  463.6  276.7  1365.0
# 3  83.9  40.7  139.3  436.7  468.5  329.1  1388.5
# 4  67.2  39.5  171.8  534.5  606.7  338.1  1649.8

# %% [markdown]
# **N.B.** have replaced the paramater definition 'delim_whitespace' keyword with "sep='\s+'" as the former is depreciated, as indicated in execution Futurewarning hints.
