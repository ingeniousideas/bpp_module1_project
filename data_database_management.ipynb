# %% [markdown]
# # Management of the SQLite Database

# %% [markdown]
# ## [Contents](#contents)

# %% [markdown]
# - [1. Overview](#overview)
# - [2. Environment Configuration](#2-environment-configuration)
# - [3. Drop Tables](#3-drop-tables)

# %% [markdown]
# ## [1. Overview](#contents)

# %% [markdown]
# ## [2. Environment Configuration](#contents)

# %%
import sqlite3
project_db  = 'data/project_db.db'

# %% [markdown]
# ## [3. Drop Tables](#contents)

# %%
# query = """
# 	DROP TABLE spring_barley_yields
# """

# query = """
# 	DROP TABLE yields_oats
# """

# query = """
# 	DROP TABLE yields_OSR
# """

# query = """
# 	DROP TABLE yields_spring_barley
# """

# query = """
# 	DROP TABLE yields_total_barley
# """

# query = """
# 	DROP TABLE yields_wheat
# """

# query = """
# 	DROP TABLE yields_winter_barley
# """



conn = sqlite3.connect(project_db)
try:
	cursor = conn.cursor()
	cursor.execute(query)

	conn.commit()
except Exception as e:
	print(f"Error executing query: {e}")
finally:
	conn.close()
